# %%
import pandas as pd

# %%
file_path_1 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_AngularJS.csv"
file_path_2 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_FrontendDeveloper.csv"
file_path_3 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_FrontendEngineer.csv"
file_path_4 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_FrontendEngineer2.csv"
file_path_5 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_ReactJS.csv"
file_path_6 = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessed_VueJS.csv"

df_1 = pd.read_csv(file_path_1, sep='$')
df_2 = pd.read_csv(file_path_2, sep='$')
df_3 = pd.read_csv(file_path_3, sep='$')
df_4 = pd.read_csv(file_path_4, sep='$')
df_5 = pd.read_csv(file_path_5, sep='$')
df_6 = pd.read_csv(file_path_6, sep='$')

# %%
df_6.sample(30)
# Out:
#            date                                 company  \
# 46   2022-12-31              Pt. Sumatra Sistem Digital
# 37   2022-10-04                                Nanovest
# 50   2022-12-23                                  Impact
# 59   2022-12-16                               Cita Kita
# 78   2022-12-22                     Maesa Group Company
# 29   2022-11-27                   Tamtech International
# 49   2023-01-30                              Deall Jobs
# 111  2023-01-27                  PT EXI GLOBAL APLIKASI
# 58   2022-11-28           Rimba Ananta Vikasa Indonesia
# 39   2022-12-04             PT. Ciptareka Asa Teknologi
# 105  2023-01-11                                  Scopic
# 27   2022-11-17           PT Quantum Sistem Intermatika
# 80   2023-01-16                                   Axdif
# 9    2022-11-24  PT. TrawlBens Teknologi Anak Indonesia
# 117  2023-01-26                  PT Pronata Data Insani
# 113  2023-01-02                                  Scopic
# ...

# %%
kolom = ['date', 'company', 'title', 'location','city','province','level','type','function','industry','title_category']
df_combined = pd.concat([df_1, df_2, df_3, df_4, df_5, df_6],axis=0, ignore_index=True)
df_combined.columns = kolom

# %%
df_combined.sample(30)
# Out:
#             date                           company  \
# 1965  2023-01-17                             Ideku
# 2675  2022-12-22                      Tech in Asia
# 1579  2022-12-23     PT Suitmedia Kreasi Indonesia
# 3460  2022-07-15                              Vimi
# 3558  2023-01-09       PT Knitto Tekstil Indonesia
# 1350  2022-12-19        Nawastra Teknologi Nimpuna
# 509   2022-12-11         PT Niaga Expert Teknologi
# 2024  2022-11-26                  PT Bank Jago Tbk
# 2166  2022-12-29                         SSDIGITAL
# 2626  2023-01-20      Blankon Technology Solutions
# 1098  2022-12-23                            Impact
# 263   2022-12-13                      ZERONE JAPAN
# 3276  2022-12-15                            Jitera
# 2882  2022-12-29             PT Verita Informatika
# 221   2022-12-09      PT. Erajaya Swasembada, Tbk.
# 2462  2023-01-28                          Catalyst
# 3508  2023-01-24                       ultraGenius
# ...

# %%
file_path_save = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessedCombine_Frontend.csv"
df_combined.to_csv(file_path_save, sep='$', index=False) #csv separator used = '$'

# %%
file_path_to_read = "G:\Coding\LearningFromYoutube\MirasBlackbox\Data-Related-Jobs-Analyst\FrontendDeveloper\LinkedInProcessedCombine_Frontend.csv"
pd_read = pd.read_csv(file_path_to_read, sep='$')
pd_read.head(30)
# Out:
#           date                                        company  \
# 0   2022-12-23                        PT. Nawa Data Solutions
# 1   2023-01-10                       Accenture Southeast Asia
# 2   2022-10-03                              Alterra Indonesia
# 3   2023-01-28                                         Zenius
# 4   2023-01-02                                          Qiwii
# 5   2022-12-28                                LanceSoft, Inc.
# 6   2023-01-27                                    Slice Group
# 7   2023-01-02                                      SIGMATECH
# 8   2022-07-23                                        Mitrais
# 9   2022-11-17                  PT Quantum Sistem Intermatika
# 10  2022-12-03                        PT. Swadharma Duta Data
# 11  2022-11-26                                KOMPAS GRAMEDIA
# 12  2023-01-05                                      SIGMATECH
# 13  2023-01-18                                      Accenture
# ...

# %%
pd_read.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3708 entries, 0 to 3707
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            3708 non-null   object
#  1   company         3708 non-null   object
#  2   title           3708 non-null   object
#  3   location        3708 non-null   object
#  4   city            3203 non-null   object
#  5   province        3083 non-null   object
#  6   level           3708 non-null   object
#  7   type            3708 non-null   object
#  8   function        3243 non-null   object
#  9   industry        2995 non-null   object
#  10  title_category  3708 non-null   object
# dtypes: object(11)
# memory usage: 318.8+ KB
